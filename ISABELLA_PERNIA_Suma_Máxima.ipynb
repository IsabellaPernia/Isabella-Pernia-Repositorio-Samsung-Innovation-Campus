# %% [markdown]
# Dados n enteros en una matriz unidimensional sucesiva, Escriba un algoritmo que encuentre cuando se maximiza la suma de los valores sucesivos de la matriz.
#
# suma = 3
#
# S = [-2, 1, -2, 4, -1, 2, 1, -5, 4]
#
# M = maximum_subarray(S)
#
# print(M)

# %%
def maximum_subarray(S):
    max_sum = float('-inf')
    current_sum = 0
    inicio = 0
    fin = 0

    for i, num in enumerate(S):
        current_sum += num

        if current_sum > max_sum:
            max_sum = current_sum
            inicio = 0
            fin = i

        if current_sum < 0:
            current_sum = 0
            inicio = i + 1

    subarray = S[inicio:fin+1]

    return subarray, max_sum

S = [-2, 1, -2, 4, -1, 2, 1, -5, 4]
M = Suma = maximum_subarray(S)
print("lista original:", S)
print(f"Subarreglo con suma máxima: {M[0]}")
print(f"Suma máxima: {suma[1]}")
# Out:
# lista original: [-2, 1, -2, 4, -1, 2, 1, -5, 4]
# Subarreglo con suma máxima: [-2, 1, -2, 4, -1, 2, 1]
# Suma máxima: 6
